# %%
import pandas as pd
import numpy as np

# %%
permutation_df = pd.read_csv("permutated_dataframe_features2")

# %%
permutation_df.head()
# Out:
#    Unnamed: 0  accumulated_distance  euclidian_distance  average_directness  \
# 0           1            124.087650           45.254834            0.364701
# 1           2             88.959860           48.662100            0.547012
# 2           3             75.803378           41.761226            0.550915
# 3           4            108.035068           74.404301            0.688705
# 4           5            470.143958           23.323808            0.049610
#
#    mean_speed  stdev_velocity  forward_migration_index_x  \
# 0    0.705043        0.566653                   0.444444
# 1    0.617777        0.583587                  -0.857143
# 2    0.861402        0.773883                  -0.833333
# 3    0.750244        0.594812                   0.647059
# 4    0.441865        0.459098                   0.042254
#
#    forward_migration_index_y   status  patientnumber treatment  track_id
# 0                  -0.363636  control            122       PBS         1
# ...

# %%
normal_df = pd.read_csv("Dataset_features_2")
normal_df.head()
# Out:
#    accumulated_distance  accumulated_euclidian_distance  average_directness  \
# 0            124.087650                       45.254834            0.364701
# 1             88.959860                       48.662100            0.547012
# 2             75.803378                       41.761226            0.550915
# 3            108.035068                       74.404301            0.688705
# 4            470.143958                       23.323808            0.049610
#
#    mean_speed  stdev_velocity  forward_migration_index_x  \
# 0    0.705043        0.566653                   0.444444
# 1    0.617777        0.583587                  -0.857143
# 2    0.861402        0.773883                  -0.833333
# 3    0.750244        0.594812                   0.647059
# 4    0.441865        0.459098                   0.042254
#
#    forward_migration_index_y   status  patientnumber treatment  track_id
# 0                  -0.363636  control            122     CXCL1         1
# ...

# %%
z = np.array([x for x in normal_df["treatment"]])
y = np.array([x for x in permutation_df["treatment"]])

# %%
y
# Out:
# array(['PBS', 'PBS', 'PBS', ..., 'CXCL8', 'CXCL8', 'PBS'], dtype='<U5')
